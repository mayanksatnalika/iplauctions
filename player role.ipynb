# %%
from bs4 import BeautifulSoup
import urllib2
import pandas as pd
import numpy as np
from dateutil import parser
import os.path
print 'imported files'
# Out:
# imported files

# %%
auc2011 = pd.read_csv('2011_auctions.csv')
pnames= []
players = auc2011['player_name']
for play in players:
    
    pnames.append(str(play.replace(' ','+')))
print(len(auc2011))
# Out:
# 119

# %%
player_id = []
cnt = 0
p_name = []
for player_name in pnames:
    
    try:
        url = 'http://www.bing.com/search?q=espncricinfo+player+' + player_name
        print url
        opener = urllib2.build_opener()
        opener.addheaders = [('User-agent', 'Mozilla/5.0')]
        page = opener.open(url)
        soup = BeautifulSoup(page.read(),"html.parser")
        print 'bing sorted'
        #finding list a and t20 urls
        divs = soup.findAll('div',{'class':'b_attribution'})
        for div in divs:
            if (div.text.find('content/player')!=-1):
                #print div.text
                parts = div.text.rsplit('/', 1)
                print parts[-1]
                player_id.append(int((parts[-1].split('.'))[0]))
                p_name.append(player_name)
                print cnt
                cnt+=1
                break

    except:
        continue
# Out:
# http://www.bing.com/search?q=espncricinfo+player+Gautam+Gambhir
# bing sorted
# 28763.html
# 0
# http://www.bing.com/search?q=espncricinfo+player+Yusuf+Pathan
# bing sorted
# 32498.html
# 1
# http://www.bing.com/search?q=espncricinfo+player+Robin+Uthappa
# bing sorted
# 35582.html
# 2
# http://www.bing.com/search?q=espncricinfo+player+Rohit+Sharma
# bing sorted
# 34102.html
# 3
# http://www.bing.com/search?q=espncricinfo+player+Irfan+Pathan
# bing sorted
# 32685.html
# 4
# http://www.bing.com/search?q=espncricinfo+player+Yuvraj+Singh
# bing sorted
# 36084.html
# 5
# http://www.bing.com/search?q=espncricinfo+player+Saurabh+Tiwary
# bing sorted
# 35390.html
# 6
# http://www.bing.com/search?q=espncricinfo+player+Mahela+Jayawardene
# bing sorted
# 49289.html
# 7
# http://www.bing.com/search?q=espncricinfo+player+David+Hussey
# bing sorted
# 5766.html
# 8
# http://www.bing.com/search?q=espncricinfo+player+Dale+Steyn
# bing sorted
# 47492.html
# 9
# http://www.bing.com/search?q=espncricinfo+player+Muttiah+Muralitharan
# bing sorted
# 49636.html
# 10
# http://www.bing.com/search?q=espncricinfo+player+Cameron+White
# bing sorted
# 8291.html
# 11
# http://www.bing.com/search?q=espncricinfo+player+Jacques+Kallis
# bing sorted
# 45789.html
# 12
# http://www.bing.com/search?q=espncricinfo+player+AB+de+Villiers
# bing sorted
# 44936.html
# 13
# http://www.bing.com/search?q=espncricinfo+player+Ross+Taylor
# bing sorted
# 38699.html
# 14
# http://www.bing.com/search?q=espncricinfo+player+Angelo+Mathews
# bing sorted
# ...
# http://www.bing.com/search?q=espncricinfo+player+Ravindra+Jadeja
# bing sorted
# 234675.html
# 15
# http://www.bing.com/search?q=espncricinfo+player+Johan+Botha
# bing sorted
# 44149.html
# 16
# http://www.bing.com/search?q=espncricinfo+player+Dinesh+Karthik
# bing sorted
# 30045.html
# 17
# 46
# http://www.bing.com/search?q=espncricinfo+player+Ishant+Sharma
# bing sorted
# 236779.html
# 47
# http://www.bing.com/search?q=espncricinfo+player+Brad+Hodge
# bing sorted
# 5674.html
# 48
# http://www.bing.com/search?q=espncricinfo+player+Shakib+Al+Hasan
# bing sorted
# 56143.html
# 49
# http://www.bing.com/search?q=espncricinfo+player+Michael+Hussey
# bing sorted
# 5939.html
# 50
# http://www.bing.com/search?q=espncricinfo+player+Brett+Lee
# bing sorted
# 6278.html
# 51
# http://www.bing.com/search?q=espncricinfo+player+Shaun+Marsh
# bing sorted
# 6683.html
# 52
# http://www.bing.com/search?q=espncricinfo+player+Stuart+Broad
# bing sorted
# 10617.html
# 53
# http://www.bing.com/search?q=espncricinfo+player+VVS+Laxman
# bing sorted
# 30750.html
# 54
# http://www.bing.com/search?q=espncricinfo+player+Murali+Kartik
# bing sorted
# 30049.html
# 55
# http://www.bing.com/search?q=espncricinfo+player+Ashok+Dinda
# bing sorted
# 227712.html
# 56
# http://www.bing.com/search?q=espncricinfo+player+Eoin+Morgan
# bing sorted
# 24598.html
# 57
# http://www.bing.com/search?q=espncricinfo+player+James+Hopes
# bing sorted
# 5702.html
# 58
# http://www.bing.com/search?q=espncricinfo+player+Ryan+Harris
# bing sorted
# 5779.html
# 59
# http://www.bing.com/search?q=espncricinfo+player+Brad+Haddin
# bing sorted
# 5560.html
# 60
# http://www.bing.com/search?q=espncricinfo+player+Callum+Ferguson
# bing sorted
# 5236.html
# 61
# http://www.bing.com/search?q=espncricinfo+player+Aaron+Finch
# bing sorted
# 5334.html
# 62
# http://www.bing.com/search?q=espncricinfo+player+Amit+Mishra
# bing sorted
# 31107.html
# 63
# http://www.bing.com/search?q=espncricinfo+player+Shikhar+Dhawan
# bing sorted
# 28235.html
# 64
# http://www.bing.com/search?q=espncricinfo+player+JP+Duminy
# bing sorted
# 44932.html
# 65
# http://www.bing.com/search?q=espncricinfo+player+Shaun+Tait
# bing sorted
# 8076.html
# 66
# http://www.bing.com/search?q=espncricinfo+player+Parthiv+Patel
# bing sorted
# 32242.html
# 67
# http://www.bing.com/search?q=espncricinfo+player+Mitchell+Marsh
# bing sorted
# 272450.html
# 68
# http://www.bing.com/search?q=espncricinfo+player+Manpreet+Gony
# bing sorted
# 317293.html
# 69
# http://www.bing.com/search?q=espncricinfo+player+Naman+Ojha
# bing sorted
# 32102.html
# 70
# http://www.bing.com/search?q=espncricinfo+player+Tim+Paine
# bing sorted
# 7252.html
# 71
# http://www.bing.com/search?q=espncricinfo+player+Abhimanyu+Mithun
# bing sorted
# 310958.html
# 72
# http://www.bing.com/search?q=espncricinfo+player+Jaydev+Unadkat
# bing sorted
# 390484.html
# 73
# http://www.bing.com/search?q=espncricinfo+player+Paul+Collingwood
# bing sorted
# 10772.html
# 74
# http://www.bing.com/search?q=espncricinfo+player+Sudeep+Tyagi
# bing sorted
# 317784.html
# 75
# http://www.bing.com/search?q=espncricinfo+player+Ajit+Agarkar
# bing sorted
# 26184.html
# 76
# http://www.bing.com/search?q=espncricinfo+player+Steven+Smith
# bing sorted
# 267192.html
# 77
# http://www.bing.com/search?q=espncricinfo+player+Dwayne+Bravo
# bing sorted
# 51439.html
# 78
# http://www.bing.com/search?q=espncricinfo+player+Owais+Shah
# bing sorted
# 20123.html
# 79
# http://www.bing.com/search?q=espncricinfo+player+Scott+Styris
# bing sorted
# 38407.html
# 80
# http://www.bing.com/search?q=espncricinfo+player+Ramesh+Powar
# bing sorted
# 32391.html
# 81
# http://www.bing.com/search?q=espncricinfo+player+Wayne+Parnell
# bing sorted
# 265564.html
# 82
# http://www.bing.com/search?q=espncricinfo+player+Ryan+ten+Doeschate
# bing sorted
# 47660.html
# 83
# http://www.bing.com/search?q=espncricinfo+player+Jesse+Ryder
# bing sorted
# 38373.html
# 84
# http://www.bing.com/search?q=espncricinfo+player+Joginder+Sharma
# bing sorted
# 29976.html
# 85
# http://www.bing.com/search?q=espncricinfo+player+Charl+Langeveldt
# bing sorted
# 45963.html
# 86
# http://www.bing.com/search?q=espncricinfo+player+Mohammad+Kaif
# bing sorted
# 29990.html
# 87
# http://www.bing.com/search?q=espncricinfo+player+Francois+du+Plessis
# bing sorted
# 44828.html
# 88
# http://www.bing.com/search?q=espncricinfo+player+Clint+McKay
# bing sorted
# 6903.html
# 89
# http://www.bing.com/search?q=espncricinfo+player+Nathan+McCullum
# bing sorted
# 37749.html
# 90
# http://www.bing.com/search?q=espncricinfo+player+James+Franklin
# bing sorted
# 37004.html
# 91
# http://www.bing.com/search?q=espncricinfo+player+Jerome+Taylor
# bing sorted
# 53191.html
# 92
# http://www.bing.com/search?q=espncricinfo+player+James+Pattinson
# bing sorted
# 272465.html
# 93
# http://www.bing.com/search?q=espncricinfo+player+Alfonso+Thomas
# bing sorted
# 47569.html
# 94
# http://www.bing.com/search?q=espncricinfo+player+Nuwan+Kulasekara
# bing sorted
# 49535.html
# 95
# http://www.bing.com/search?q=espncricinfo+player+Matthew+Wade
# bing sorted
# 230193.html
# 96
# http://www.bing.com/search?q=espncricinfo+player+Dimitri+Mascarenhas
# bing sorted
# 16932.html
# 97
# http://www.bing.com/search?q=espncricinfo+player+Colin+Ingram
# bing sorted
# 45705.html
# 98
# http://www.bing.com/search?q=espncricinfo+player+Ben+Hilfenhaus
# bing sorted
# 5941.html
# 99
# http://www.bing.com/search?q=espncricinfo+player+Pankaj+Singh
# bing sorted
# 32973.html
# 100
# http://www.bing.com/search?q=espncricinfo+player+Rusty+Theron
# bing sorted
# 223642.html
# 101
# http://www.bing.com/search?q=espncricinfo+player+Suraj+Randiv
# bing sorted
# 50438.html
# 102
# http://www.bing.com/search?q=espncricinfo+player+John+Hastings
# bing sorted
# 228622.html
# 103
# http://www.bing.com/search?q=espncricinfo+player+Andrew+McDonald
# bing sorted
# 6553.html
# 104
# http://www.bing.com/search?q=espncricinfo+player+Michael+Lumb
# bing sorted
# 16406.html
# 105
# http://www.bing.com/search?q=espncricinfo+player+Michael+Klinger
# bing sorted
# 6161.html
# 106
# http://www.bing.com/search?q=espncricinfo+player+Moises+Henriques
# bing sorted
# 5961.html
# 107
# http://www.bing.com/search?q=espncricinfo+player+George+Bailey
# bing sorted
# 4451.html
# 108
# http://www.bing.com/search?q=espncricinfo+player+Roelof+van+der+Merwe
# bing sorted
# 47850.html
# 109
# http://www.bing.com/search?q=espncricinfo+player+Rilee+Rossouw
# bing sorted
# 318845.html
# 110
# http://www.bing.com/search?q=espncricinfo+player+Nuwan+Pradeep
# bing sorted
# ...
# http://www.bing.com/search?q=espncricinfo+player+Travis+Birt
# bing sorted
# 4292.html
# 111
# http://www.bing.com/search?q=espncricinfo+player+Nathan+Rimmington
# bing sorted
# 7443.html
# 112
# http://www.bing.com/search?q=espncricinfo+player+Jonathan+Vandiar
# bing sorted
# 285687.html
# 113
# http://www.bing.com/search?q=espncricinfo+player+Aiden+Blizzard
# bing sorted
# 4498.html
# 114
# http://www.bing.com/search?q=espncricinfo+player+Robert+Frylinck
# bing sorted
# 45204.html
# 115
# http://www.bing.com/search?q=espncricinfo+player+Stephen+O'Keefe
# bing sorted
# 7069.html
# 116

# %%
player_id
# Out:
# [28763,
#  32498,
#  35582,
#  34102,
#  32685,
#  36084,
#  35390,
#  49289,
#  5766,
#  47492,
#  49636,
#  8291,
#  45789,
#  44936,
#  38699,
#  234675,
#  44149,
#  30045,
#  32966,
#  34274,
#  5390,
#  30102,
#  4864,
#  26421,
#  31820,
#  7702,
#  26806,
#  30732,
#  219889,
#  376116,
#  32965,
#  50710,
#  32540,
#  4508,
#  6981,
#  48472,
#  19296,
#  38710,
#  32130,
#  28114,
#  47270,
#  35280,
#  26829,
#  35565,
#  46538,
#  37737,
#  35731,
#  236779,
#  5674,
#  56143,
#  5939,
#  6278,
#  6683,
#  10617,
#  30750,
#  30049,
#  227712,
#  24598,
#  5702,
#  5779,
#  5560,
#  5236,
#  5334,
#  31107,
#  28235,
#  44932,
#  8076,
#  32242,
#  272450,
#  317293,
#  32102,
#  7252,
#  310958,
#  390484,
#  10772,
#  317784,
#  26184,
#  267192,
#  51439,
#  20123,
#  38407,
#  32391,
#  265564,
#  47660,
#  38373,
#  29976,
#  45963,
#  29990,
#  44828,
#  6903,
#  37749,
#  37004,
#  53191,
#  272465,
#  47569,
#  49535,
#  230193,
#  16932,
#  45705,
#  5941,
#  32973,
#  223642,
#  50438,
#  228622,
#  6553,
#  16406,
#  6161,
#  5961,
#  4451,
#  47850,
#  318845,
#  4292,
#  7443,
#  285687,
#  4498,
#  45204,
#  7069]

# %%
len(p_name)
# Out:
# 117

# %%
pids = pd.DataFrame()
pids['pname']  = p_name
pids['id'] = player_id

# %%
pd.to_csv('2011cricinfo_playerids.csv')
